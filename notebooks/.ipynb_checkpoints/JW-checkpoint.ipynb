# %%
import numpy as np
import pandas as pd

# %% [markdown]
# For this assignment, I decided to investigate trends in cryptocurrency markets. I found two relevant datasets, both on Kaggle.
#  - https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory/
#  - https://www.kaggle.com/jessevent/all-crypto-currencies
#
# The first dataset includes price data for many different coins, spread across several "csv"s. I choose to focus
# specifically on the value of Bitcoin in USD over time.

# %%
df = pd.read_csv("../data/cryptocurrencypricehistory/bitcoin_cash_price.csv")
df
# Out:
#              Date     Open     High      Low    Close       Volume  \
# 0    Feb 20, 2018  1543.27  1569.03  1414.35  1418.73  820,947,000
# 1    Feb 19, 2018  1483.34  1553.81  1483.34  1534.77  578,906,000
# 2    Feb 18, 2018  1552.10  1641.40  1428.49  1487.46  907,873,000
# 3    Feb 17, 2018  1548.48  1568.64  1517.14  1551.39  641,719,000
# 4    Feb 16, 2018  1373.16  1558.66  1369.68  1552.20  961,010,000
# ..            ...      ...      ...      ...      ...          ...
# 208  Jul 27, 2017   417.10   460.97   367.78   385.48      533,207
# 209  Jul 26, 2017   407.08   486.16   321.79   365.82    1,784,640
# 210  Jul 25, 2017   441.35   541.66   338.09   406.90      524,908
# 211  Jul 24, 2017   412.58   578.89   409.21   440.70      190,952
# 212  Jul 23, 2017   555.89   578.97   411.78   413.06       85,013
#
#          Market Cap
# 0    26,199,800,000
# 1    25,179,700,000
# 2    26,344,200,000
# 3    26,280,100,000
# 4    23,302,000,000
# ..              ...
# ...

# %% [markdown]
# From this sneak-peak of the raw data, we can see an overall upward trend in value over the time range. Let's try to visualize the entire history covered by the dataset:

# %%
df.plot(x='Date')

# %% [markdown]
# Looking at this graph, I see the dates are backwards. Let's investigate the type of the "Date" column.

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %% [markdown]
# The "Date" column is a generic object. Let's try to parse it into a familiar format.

# %%
df['Date']  = pd.to_datetime(df['Date'])
df.plot(x='Date')

# %% [markdown]
# Now this graph is sensible and legible!
#
# This graph shows a period of relative stabililty, followed by an interesting spike and crash. Additionally, we see that the high/low columns can occasionally depart dramatically from the other attributes, but in gernal, they follow the same trends.

# %% [markdown]
# Now let's look at the second dataset:

# %%
df2 = pd.read_csv("../data/crypto-markets.csv")
df2
# Out:
#              slug symbol       name        date  ranknow      open      high  \
# 0         bitcoin    BTC    Bitcoin  2013-04-28        1    135.30    135.98
# 1         bitcoin    BTC    Bitcoin  2013-04-29        1    134.44    147.49
# 2         bitcoin    BTC    Bitcoin  2013-04-30        1    144.00    146.93
# 3         bitcoin    BTC    Bitcoin  2013-05-01        1    139.00    139.89
# 4         bitcoin    BTC    Bitcoin  2013-05-02        1    116.38    125.60
# ...           ...    ...        ...         ...      ...       ...       ...
# 942292  project-x  NANOX  Project-X  2018-11-26     1727  22424.60  23049.30
# 942293  project-x  NANOX  Project-X  2018-11-27     1727  20711.90  23742.10
# 942294  project-x  NANOX  Project-X  2018-11-28     1727  23320.90  25235.10
# 942295  project-x  NANOX  Project-X  2018-11-29     1727  24543.53  24582.47
# 942296  project-x  NANOX  Project-X  2018-11-30     1727  22872.09  23086.98
#
# ...

# %% [markdown]
# This dataset is monolithic; it contains market history for a vast array of coins. I only want to know about bitcoin, so I will filter the rest out.

# %%
df2 = df2[df2['symbol']=="BTC"]
df2
# Out:
#          slug symbol     name        date  ranknow     open     high      low  \
# 0     bitcoin    BTC  Bitcoin  2013-04-28        1   135.30   135.98   132.10
# 1     bitcoin    BTC  Bitcoin  2013-04-29        1   134.44   147.49   134.00
# 2     bitcoin    BTC  Bitcoin  2013-04-30        1   144.00   146.93   134.05
# 3     bitcoin    BTC  Bitcoin  2013-05-01        1   139.00   139.89   107.72
# 4     bitcoin    BTC  Bitcoin  2013-05-02        1   116.38   125.60    92.28
# ...       ...    ...      ...         ...      ...      ...      ...      ...
# 2037  bitcoin    BTC  Bitcoin  2018-11-25        1  3880.78  4120.87  3585.06
# 2038  bitcoin    BTC  Bitcoin  2018-11-26        1  4015.07  4107.14  3643.92
# 2039  bitcoin    BTC  Bitcoin  2018-11-27        1  3765.95  3862.96  3661.01
# 2040  bitcoin    BTC  Bitcoin  2018-11-28        1  3822.47  4385.90  3822.47
# 2041  bitcoin    BTC  Bitcoin  2018-11-29        1  4269.00  4413.02  4145.77
#
# ...

# %% [markdown]
# This dataset still has many attributes we don't care about. Let's prune off everything that isn't included in the first dataset.

# %%
df2 = df2.loc[:, ['date', 'open', 'high', 'low', 'close']]
df2
# Out:
#             date     open     high      low    close
# 0     2013-04-28   135.30   135.98   132.10   134.21
# 1     2013-04-29   134.44   147.49   134.00   144.54
# 2     2013-04-30   144.00   146.93   134.05   139.00
# 3     2013-05-01   139.00   139.89   107.72   116.99
# 4     2013-05-02   116.38   125.60    92.28   105.21
# ...          ...      ...      ...      ...      ...
# 2037  2018-11-25  3880.78  4120.87  3585.06  4009.97
# 2038  2018-11-26  4015.07  4107.14  3643.92  3779.13
# 2039  2018-11-27  3765.95  3862.96  3661.01  3820.72
# 2040  2018-11-28  3822.47  4385.90  3822.47  4257.42
# 2041  2018-11-29  4269.00  4413.02  4145.77  4278.85
#
# [2042 rows x 5 columns]

# %% [markdown]
# Just like the last dataset, let's investigate the type of the "Date" column, and parse it into a better format if need be.

# %%
df2.dtypes
# Out:
# date      object
# open     float64
# high     float64
# low      float64
# close    float64
# dtype: object

# %%
df2['date']  = pd.to_datetime(df2['date'])
df2.plot(x='date')

# %% [markdown]
# It appears we are witnessing the same spike at the the beginning of 2018! Finally, let us try to combine the data. To do so, I'll need to further prune the columns, as well as rename them, so that the dataframes match.

# %%
df = df.loc[:, ['Date', 'Open', 'High', 'Low', 'Close']]
df2.columns =  ['Date', 'Open', 'High', 'Low', 'Close']
df3 = pd.concat([df, df2])
df3
# Out:
#            Date     Open     High      Low    Close
# 0    2018-02-20  1543.27  1569.03  1414.35  1418.73
# 1    2018-02-19  1483.34  1553.81  1483.34  1534.77
# 2    2018-02-18  1552.10  1641.40  1428.49  1487.46
# 3    2018-02-17  1548.48  1568.64  1517.14  1551.39
# 4    2018-02-16  1373.16  1558.66  1369.68  1552.20
# ...         ...      ...      ...      ...      ...
# 2037 2018-11-25  3880.78  4120.87  3585.06  4009.97
# 2038 2018-11-26  4015.07  4107.14  3643.92  3779.13
# 2039 2018-11-27  3765.95  3862.96  3661.01  3820.72
# 2040 2018-11-28  3822.47  4385.90  3822.47  4257.42
# 2041 2018-11-29  4269.00  4413.02  4145.77  4278.85
#
# [2255 rows x 5 columns]

# %%
df3.plot(x='Date')

# %% [markdown]
# It seems that the datasets differ on their y-axis scale. The first dataset specifically claims to be price in USD, while the second only says "price". Perhaps it is with respect to a different currency. Regardless, since the goal is just to identify broad trends, and the shape of the graphs seems to otherwise be consistent, let's try to normalize the second with respect to the first. To do so, I'll linearly scale the second dataset such that the two datasets have the same min and max in the interval they overlap.

# %%
df2_overlapping = df2[(df2['Date'] >= df['Date'].min()) & (df2['Date'] <= df['Date'].max())]

def normalize(v):
    min1 = df['Open'].min()
    max1 = df['Open'].max()
    len1 = max1-min1
    min2 = df2_overlapping['Open'].min()
    max2 = df2_overlapping['Open'].max()
    len2 = max2-min2
    return (v - min2)*((len1)/(len2))+min1

df2_scaled = df2.copy()
df2_scaled.loc[:,['Open','High','Low','Close']] = df2_scaled.loc[:,['Open','High','Low','Close']].apply(normalize)
df2_scaled
# Out:
#            Date        Open        High         Low       Close
# 0    2013-04-28 -312.406818 -312.258396 -313.105275 -312.644730
# 1    2013-04-29 -312.594529 -309.746135 -312.690566 -310.390025
# 2    2013-04-30 -310.507889 -309.868365 -312.679653 -311.599228
# 3    2013-05-01 -311.599228 -311.404970 -318.426642 -316.403300
# 4    2013-05-02 -316.536444 -314.524015 -321.796696 -318.974494
# ...         ...         ...         ...         ...         ...
# 2037 2018-11-25  505.110558  557.514454  440.564428  533.308564
# 2038 2018-11-26  534.421730  554.517638  453.411666  482.923644
# 2039 2018-11-27  480.046875  501.221027  457.141861  492.001398
# 2040 2018-11-28  492.383367  615.361948  492.383367  587.318911
# 2041 2018-11-29  589.846451  621.281368  562.949320  591.996388
#
# [2042 rows x 5 columns]

# %%
df4 = pd.concat([df, df2_scaled])
df4.plot(x='Date')

# %% [markdown]
# Now the data appears to be in agreement. We now have a single graph with a rich history of Bitcoin price trends, particularily surrounding the 2018 spike. However, the data is only useful in its general shape; the y values are clearly unasable. The values of the second dataset were drastically altered to match the scale of the first. In fact, a large portion of the data shows a negative selling price. Still, the fact that the datasets were able to match under a simple linear scaling shows that the datasets generally agree on the trends in the history of Bitcoin pricing.
